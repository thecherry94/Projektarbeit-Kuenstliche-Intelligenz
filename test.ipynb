# %%
import os
import pathlib as pl
from matplotlib import pyplot as plt
from PIL import Image
from DataAugmentation import *
import cv2
import numpy as nps
import random

# %matplotlib inline
# Out:
# e:\Uni\Kuenstliche-Intelligenz\Projektarbeit\Projektarbeit-Kuenstliche-Intelligenz\DataAugmentation.py:264: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if len(img.shape) is 3 and not isinstance(padColor, (list, tuple, np.ndarray)): # color image but only one color provided

# %%
DataAugmentation.process()
# Out:
# 0.3
# -0.23
# -0.2
# 0.29
# -0.09
# 0.079
# 0.16
# 0.136
# -0.16
# 0.065
# -0.18
# 0.26
# -0.25
# 0.2
# 0.53
# 0.117
# 0.116
# 0.062
# 0.049
# 0.046
# -0.18
# 0.13
# 0.25
# 0.16
# 0.24
# 0.31
# 0.085
# 0.133
# 0.01947
# 0.25
# 0.25
# 0.27
# 0.26
# -0.09
# 0.11
# 0.0359
# 0.08
# -0.09
# -0.19
# 0.57
# 0.08
# 0.13
# 0.31
# 0.03407
# -0.24
# 0.01
# -0.31
# -0.29
# 0.02
# -0.1
# 0.76
# 0.085
# 0.19
# 0.03
# 0.01
# 0.24
# -0.06
# 0.18
# -0.27
# -0.3
# -0.3
# 0.17
# 0.27
# 0.68
# 0.11
# 0.3
# -0.18
# -0.29
# 0.31
# -0.09
# -0.28
# -0.29
# 0.056
# 0.082
# 0.00898
# -0.22
# 0.25
# 0.25
# 0.17
# 0.2068
# 0.91
# -0.02
# 0.16
# 0.17
# 0.04
# 0.061
# 0.141
# 0.28
# 0.11
# 0.07
# 0.0
# -0.2
# -0.05
# 0.01
# 0.15
# 0.19
# 0.049
# -0.03
# 0.09
# 0.002
# 0.025
# -0.05
# 0.11
# -0.15
# -0.23
# -0.14
# -0.25
# -0.06
# -0.27
# 0.03
# 0.02
# 0.1
# 0.53
# 0.173
# 0.024
# 0.125
# -0.27
# 0.26
# 0.93
# 0.195
# 0.048
# 0.04
# -0.16
# -0.29
# 0.42
# 0.109
# 0.21
# 0.32
# -0.2
# -0.23
# -0.31
# 0.01
# 0.21
# 0.188
# 0.164
# 0.142
# 0.25
# -0.03
# 0.13
# -0.13
# 0.11
# 0.035
# 0.02
# 0.11
# -0.15
# 0.05
# -0.11
# -0.04
# 0.63
# -0.3
# 0.07
# -0.19
# 0.01
# 0.17
# 0.26
# 0.09
# 0.48
# 0.062
# 0.00991
# -0.07
# 0.22
# 0.82
# 0.082
# 0.109
# 0.111
# -0.2
# -0.12
# 0.04
# 0.02
# -0.05
# 0.01
# -0.06
# 0.97
# 0.069
# 0.184
# 0.06
# -0.07
# -0.23
# -0.01
# -0.07
# -0.18
# 0.23
# 0.079
# 0.117
# 0.133
# -0.08
# -0.16
# 0.14
# -0.09
# 0.16
# -0.3
# 0.25
# -0.3
# 0.26
# 0.43
# 0.007
# 0.117
# 0.13
# -0.04
# 0.14
# 0.14
# 0.012
# 0.12
# 0.08
# -0.02
# 0.06
# -0.04
# 0.161
# 0.055
# 0.146
# 0.034
# -0.11
# -0.16
# 0.14
# 0.07
# 0.103
# 0.038
# 0.132
# 0.2
# 0.09
# 0.31
# 0.29
# -0.12
# 0.11
# 0.3
# 0.071
# 0.175
# 0.085
# 0.038
# 0.179
# 0.31
# 0.32
# 0.037
# -0.29
# 0.98
# 0.137
# -0.13
# -0.03
# -0.29
# -0.17
# -0.32
# 0.71
# 0.035
# 0.035
# 0.078
# -0.2
# 0.07
# -0.33
# 0.16
# 0.2
# 0.076
# -0.23
# 0.12
# -0.3
# 0.29
# -0.07
# 0.16
# 0.118
# 0.03
# 0.27
# 0.15
# 0.077
# 0.31
# 0.22
# 0.132
# 0.16
# 0.121
# 0.175
# 0.09
# 0.007
# 0.153
# -0.25
# 0.49
# 0.28
# -0.29
# 0.3
# -0.21
# 0.16
# 0.0429
# 0.1
# 0.148
# 0.133
# -0.08
# -0.04
# -0.09
# 0.25
# 0.05
# 0.192
# 0.02326
# 0.23
# 0.31
# 0.02
# 0.17
# 0.23
# 0.51
# -0.07
# -0.12
# -0.27
# 0.12
# -0.3
# 0.89
# 0.16
# 0.023
# 0.01
# 0.32
# -0.16
# 0.21
# -0.18
# 0.14
# 0.28
# 0.22
# 0.64
# 0.081
# 0.156
# 0.2
# 0.32
# 0.24
# 0.102
# 0.09
# 0.01
# 0.05
# -0.09
# -0.19
# 0.091
# 0.26
# 0.19
# -0.13
# 0.001
# -0.26
# -0.06
# -0.19
# 0.28
# 0.19
# -0.06
# -0.14
# 0.24
# 0.08
# 0.018
# 0.182
# -0.27
# -0.08
# 0.02
# -0.02
# -0.15
# 0.32
# 0.017
# 0.116
# 0.154
# 0.08
# 0.01
# -0.01
# -0.12
# 0.132
# 0.182
# 0.021
# 0.084
# 0.16
# 0.03
# 0.06
# 0.064
# 0.181
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-b857057f4a9b> in <module>
# ----> 1 DataAugmentation.process()
#
# e:\Uni\Kuenstliche-Intelligenz\Projektarbeit\Projektarbeit-Kuenstliche-Intelligenz\DataAugmentation.py in process(path, options)
#     208
#     209                 for ratio in zoomRatios:
# --> 210                     auglist.append(zoom(image, ratio))
#     211
#     212                 for ratio in channelShiftRatios:
#
# e:\Uni\Kuenstliche-Intelligenz\Projektarbeit\Projektarbeit-Kuenstliche-Intelligenz\DataAugmentation.py in zoom(img, value)
#     357     w_start = random.randint(0, w-w_taken)
#     358     img = img[h_start:h_start+h_taken, w_start:w_start+w_taken, :]
# --> 359     img = fill(img, h, w)
#     360     return img
#     361
#
# e:\Uni\Kuenstliche-Intelligenz\Projektarbeit\Projektarbeit-Kuenstliche-Intelligenz\DataAugmentation.py in fill(img, h, w)
#     291
#     292 def fill(img, h, w):
# --> 293     img = cv2.resize(img, (h, w), cv2.INTER_CUBIC)
#     294     return img
#     295
#
# error: OpenCV(4.0.1) C:\ci\opencv-suite_1573470242804\work\modules\imgproc\src\resize.cpp:3784: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
